# %% [markdown]
# # Analysis of contingency tables

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import chi2
from scipy.stats import chi2_contingency

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Get current working directory
print(os.getcwd())
# Out:
# C:\Dev\Studium\Sem5\DA\data_analytics\Week_07

# %% [markdown]
# ## Import the apartment data

# %%
# Define columns
columns = ['web-scraper-order',
            'address_raw',
            'lat',
            'lon',
            'bfs_number',
            'bfs_name',
            'rooms', 
            'area', 
            'luxurious', 
            'price', 
            'price_per_m2',
            'pop_dens',
            'frg_pct',
            'mean_taxable_income',
            'dist_supermarket']

# Read and select variables
df_orig = pd.read_csv("apartments_data_enriched_cleaned.csv", sep=";")[columns]

# Rename variable 'web-scraper-order' to 'apmt_id'
df_orig = df_orig.rename(columns={'web-scraper-order': 'apartment_id'})

# Remove missing values
df = df_orig.dropna()
df.head(5)

# Remove duplicates
df = df.drop_duplicates()
df.head(5)
# Out:
#      apartment_id                           address_raw        lat       lon  \
# 0    1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH  47.252171  8.845797
# 1  1693998233-172   Widacherstrasse 5, 8630 Rüti ZH, ZH  47.252087  8.854919
# 2  1693998256-331         Widenweg 14, 8630 Rüti ZH, ZH  47.253670  8.853993
# 3  1693998265-381              Rain 1, 8630 Rüti ZH, ZH  47.259834  8.851705
# 4  1693998276-419  Bachtelstrasse 24b, 8630 Rüti ZH, ZH  47.266113  8.866872
#
#    bfs_number   bfs_name  rooms  area  luxurious  price  price_per_m2  \
# 0         118  Rüti (ZH)    3.0    49          0   1441         29.41
# 1         118  Rüti (ZH)    3.0   111          0   2600         23.42
# 2         118  Rüti (ZH)    3.0    58          0   1490         25.69
# 3         118  Rüti (ZH)    4.0   118          0   3240         27.46
# 4         118  Rüti (ZH)    3.0    66          0   1450         21.97
#
#       pop_dens    frg_pct  mean_taxable_income  dist_supermarket
# 0  1221.272366  24.841283          65362.04268        645.652248
# 1  1221.272366  24.841283          65362.04268        265.102153
# 2  1221.272366  24.841283          65362.04268         94.401821
# 3  1221.272366  24.841283          65362.04268        106.660970
# 4  1221.272366  24.841283          65362.04268        974.844209

# %% [markdown]
# ## Create a new categorical variable based on the price_per_m2

# %% [markdown]
# ### Plot histogram of price_per_m2

# %%
# Plot Histogram
fig = plt.figure( figsize=(7,4))
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14, rotation=0)
n, bins, patches = plt.hist(x=df['price_per_m2'], 
                            bins=20, 
                            color='#42AD12',
                            alpha=0.5, 
                            rwidth=0.95
                   )
plt.grid(True)
plt.ticklabel_format(style='plain')
plt.grid(axis='y', alpha=0.75)

# Set labels
plt.xlabel('price_per_m2', fontsize=10, labelpad=10)
plt.ylabel('Frequency', fontsize=10, labelpad=10)
plt.title('Histogram of price_per_m2', fontsize=12, pad=10)

# Set fontsize of tick labels
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)

plt.show()

# %% [markdown]
# ### Show quantiles of price_per_m2

# %%
qt_price = df['price_per_m2'].quantile(q=[0.10, 0.25, 0.50, 0.75, 0.90]).round(1)
qt_price
# Out:
# 0.10    20.4
# 0.25    23.4
# 0.50    28.0
# 0.75    38.0
# 0.90    51.6
# Name: price_per_m2, dtype: float64

# %% [markdown]
# ### Create new categorical variable 'price_cat'

# %%
# Create labels
labels = ['0 - 19', '20 - 24', '25 - 29', '30 - 34', '>= 35']

# Create new categorical variable
df["price_cat"] = pd.cut(df.price_per_m2, bins=[0, 20, 25, 30, 35, 150], labels=labels)

# Check values
df[['price_per_m2', 'price_cat']].head(10)
# Out:
#    price_per_m2 price_cat
# 0         29.41   25 - 29
# 1         23.42   20 - 24
# 2         25.69   25 - 29
# 3         27.46   25 - 29
# 4         21.97   20 - 24
# 5         21.43   20 - 24
# 6         28.46   25 - 29
# 7         23.96   20 - 24
# 8         30.29   30 - 34
# 9         17.80    0 - 19

# %% [markdown]
# ## Create a new categorical variable based on the living area

# %% [markdown]
# ### Plot histogram of area

# %%
# Plot Histogram
fig = plt.figure( figsize=(7,4))
plt.xticks(fontsize=14, rotation=0)
plt.yticks(fontsize=14, rotation=0)
n, bins, patches = plt.hist(x=df['area'], 
                            bins=20, 
                            color='blue',
                            alpha=0.5, 
                            rwidth=0.95
                   )
plt.grid(True)
plt.ticklabel_format(style='plain')
plt.grid(axis='y', alpha=0.75)

# Set labels
plt.xlabel('area (m2)', fontsize=10, labelpad=10)
plt.ylabel('Frequency', fontsize=10, labelpad=10)
plt.title('Histogram of area', fontsize=12, pad=10)

# Set fontsize of tick labels
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)

plt.show()

# %% [markdown]
# ### Show quantiles of area

# %%
qt_area = df['area'].quantile(q=[0.10, 0.25, 0.50, 0.75, 0.90]).round(1)
qt_area
# Out:
# 0.10     43.0
# 0.25     63.2
# 0.50     86.0
# 0.75    108.0
# 0.90    140.0
# Name: area, dtype: float64

# %% [markdown]
# ### Create new categorical variable 'area_cat'

# %%
# Create labels
labels = ['0 - 49', '50 - 74', '75 - 99', '100 - 149', '>= 150']

# Create new categorical variable
df["area_cat"] = pd.cut(df['area'], bins=[0, 50, 75, 100, 150, 1000], labels=labels)

# Check values
df[['area', 'area_cat']].head(10)
# Out:
#    area   area_cat
# 0    49     0 - 49
# 1   111  100 - 149
# 2    58    50 - 74
# 3   118  100 - 149
# 4    66    50 - 74
# 5    61    50 - 74
# 6    65    50 - 74
# 7   101  100 - 149
# 8    68    50 - 74
# 9   191     >= 150

# %% [markdown]
# ## Create a contingency table with the number of apartments per 'area_cat' versus 'price_cat'

# %%
# Contingency table (numbers in the table are apartments)
tab = pd.pivot_table(df[['apartment_id', 'area_cat', 'price_cat']],
                     index=['area_cat'],
                     columns=['price_cat'], 
                     aggfunc='count')
tab
# Out:
#           apartment_id
# price_cat       0 - 19 20 - 24 25 - 29 30 - 34 >= 35
# area_cat
# 0 - 49               2       2       4      13    84
# 50 - 74              1      40      58      31    64
# 75 - 99             19      73      66      21    48
# 100 - 149           31      80      47      22    21
# >= 150              20       8       6       5     8

# %% [markdown]
# ## Perform a Chi-square test on the contingency table
# For details see: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html

# %%
# 1-alpha
prob = 0.95

# Chi-squared test
stat, p, dof, expected = chi2_contingency(tab)

# Critical value
critical = chi2.ppf(prob, dof)

# Print results of the Chi-square test
print('Expected frequencies:', '\n', expected.round(4), '\n')
print('Critical value:', critical.round(4), '\n')
print('Test statistic:', stat.round(4), '\n')
print('Degrees of freedom:', dof, '\n')
print(f'p-value: {p:.4f}')
# Out:
# Expected frequencies:
#  [[ 9.9031 27.5388 24.5543 12.4806 30.5233]
#  [18.2972 50.8811 45.3669 23.0594 56.3953]
#  [21.4096 59.5362 53.084  26.9819 65.9884]
#  [18.9574 52.7171 47.0039 23.8915 58.4302]
#  [ 4.4328 12.3269 10.991   5.5866 13.6628]]
#
# Critical value: 26.2962
#
# Test statistic: 286.3147
#
# Degrees of freedom: 16
#
# p-value: 0.0000

# %% [markdown]
# ## Interpretation of the Chi-squared test result

# %% [markdown]
# <p>Because the test statistic is larger than the critical value and the p-value is smaller than our significance level apha=0.05, we can reject the null hypothesis, i.e. there is a statistically significant (at the 0.05 significance-level) association between the price-categories and the living-area categories in the contingence table.</p>

# %% [markdown]
# ## Applying the Chi-squared test to animal behavior
#
# For full study see: https://davida-rosenstrauch.medium.com/applying-the-chi-squared-test-to-animal-behavior-b6cca3f930b8

# %% [markdown]
# <img src="https://miro.medium.com/max/640/1*h5JgsNbUy2tuiLgSrkIlyA.png" width="500" align="left"/>

# %% [markdown]
# ### Contingency table, spotted hyena example

# %%
# The numpy array shows how many times each hyena responded (see study above)
table = np.array([[0,4],
                  [7,6],
                  [9,0],
                  [15,10]])

# Create a data frame from 'table'
df_hy = pd.DataFrame(table, columns=[['Female', 'Male']],
             index=['Fear', 'Greeting', 'Aggression', 'No Response'])
df_hy
# Out:
#             Female Male
# Fear             0    4
# Greeting         7    6
# Aggression       9    0
# No Response     15   10

# %% [markdown]
# ### b) Perform a Chi-squared test based on the table above.

# %%
table = df_hy.values
chi2_stat, p, dof, expected = chi2_contingency(table)

print('Expected frequencies:', '\n', expected.round(4), '\n')
print(f'p-value: {p:.4f}')
print('Test statistic:', chi2_stat.round(4))
print('Degrees of freedom:', dof)
# Out:
# Expected frequencies:
#  [[ 2.4314  1.5686]
#  [ 7.902   5.098 ]
#  [ 5.4706  3.5294]
#  [15.1961  9.8039]]
#
# p-value: 0.0065
# Test statistic: 12.2754
# Degrees of freedom: 3

# %% [markdown]
# ### c) Write a Python function which calculates the expected frequencies of the contingency table.

# %%
def expected_frequencies(data):
    """
    Calculate expected frequencies for a contingency table.

    Parameters:
        data (numpy.ndarray or pandas.DataFrame): observed frequencies.

    Returns:
        numpy.ndarray: expected frequencies of the same shape as input.
    """
    # Convert DataFrame to numpy array if necessary
    if isinstance(data, pd.DataFrame):
        observed = data.values
    elif isinstance(data, np.ndarray):
        observed = data
    else:
        raise TypeError("Input must be a numpy array or pandas DataFrame.")

    # Calculate row sums, column sums, and total sum
    row_sums = observed.sum(axis=1, keepdims=True)
    col_sums = observed.sum(axis=0, keepdims=True)
    total = observed.sum()

    # Compute expected frequencies
    expected = row_sums @ col_sums / total

    # Return as DataFrame if input was DataFrame
    if isinstance(data, pd.DataFrame):
        return pd.DataFrame(expected, index=data.index, columns=data.columns)
    else:
        return expected

# Calculate expected frequencies
expected_custom = expected_frequencies(df_hy)

print("\nExpected frequencies:")
print(expected_custom)
# Out:
# Expected frequencies:
#                 Female      Male
# Fear          2.431373  1.568627
# Greeting      7.901961  5.098039
# Aggression    5.470588  3.529412
# No Response  15.196078  9.803922

# %% [markdown]
# ### d) Compare your calculated expected frequencies with those from the chi2_contingency() method in Python.

# %%
print('Expected frequencies (chi2_contingency()):', '\n', expected, '\n')
print('Expected frequencies (custom function):', '\n', expected_custom, '\n')

difference = np.abs(expected - expected_custom)
print('Difference between both methods:', '\n', difference)
# Out:
# Expected frequencies (chi2_contingency()):
#  [[ 2.43137255  1.56862745]
#  [ 7.90196078  5.09803922]
#  [ 5.47058824  3.52941176]
#  [15.19607843  9.80392157]]
#
# Expected frequencies (custom function):
#                  Female      Male
# Fear          2.431373  1.568627
# Greeting      7.901961  5.098039
# Aggression    5.470588  3.529412
# No Response  15.196078  9.803922
#
# Difference between both methods:
#              Female Male
# Fear           0.0  0.0
# Greeting       0.0  0.0
# Aggression     0.0  0.0
# No Response    0.0  0.0

# %% [markdown]
# ### e) Extent the Python function under c) to additionally provide the Chi-square test statistic.

# %%
def chi_square_test(data):
    """
    Calculate expected frequencies and Chi-square test statistic for a contingency table.

    Parameters:
        data (numpy.ndarray or pandas.DataFrame): Observed frequencies.

    Returns:
        expected (pandas.DataFrame or numpy.ndarray): Expected frequencies.
        chi2 (float): Chi-square test statistic.
    """
    # Convert to numpy array if needed
    if isinstance(data, pd.DataFrame):
        observed = data.values
        is_df = True
    elif isinstance(data, np.ndarray):
        observed = data
        is_df = False
    else:
        raise TypeError("Input must be a numpy array or pandas DataFrame.")

    # Compute expected frequencies
    row_sums = observed.sum(axis=1, keepdims=True)
    col_sums = observed.sum(axis=0, keepdims=True)
    total = observed.sum()
    expected = row_sums @ col_sums / total

    # Compute Chi-square statistic
    chi2 = ((observed - expected) ** 2 / expected).sum()

    # Convert expected back to DataFrame if input was one
    if is_df:
        expected = pd.DataFrame(expected, index=data.index, columns=data.columns)

    return expected, chi2

# Calculate expected frequencies
expected_custom, chi_square_custom = chi_square_test(df_hy)

print("\nExpected frequencies:\n", expected_custom)
print("\nChi-square test statistic:\n", chi_square_custom)
# Out:
# Expected frequencies:
#                  Female      Male
# Fear          2.431373  1.568627
# Greeting      7.901961  5.098039
# Aggression    5.470588  3.529412
# No Response  15.196078  9.803922
#
# Chi-square test statistic:
#  12.27543424317618

# %% [markdown]
# ### f) Compare your calculated Chi-square test statistic with the Chi-square test statistic from the chi2_contingency() method in Python.

# %%
print("Chi-square test statistic (chi2_contingency()):", chi2_stat)
print ("Chi-square test statistic (custom function):", chi_square_custom)

difference = np.abs(chi2_stat - chi_square_custom)
print("Difference between both methods:", difference)
# Out:
# Chi-square test statistic (chi2_contingency()): 12.27543424317618
# Chi-square test statistic (custom function): 12.27543424317618
# Difference between both methods: 0.0

# %% [markdown]
# ### g) In the Jupyter notebook, state in one sentence whether the results of the original study are correct or not.
#
# The results of the original study are correct, as the Chi-squared test confirms a significant association with the Chi-square value greater than the critical value and p less than 0.05.

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 11
# Datetime: 2025-10-29 19:14:20
# Python Version: 3.13.7
# -----------------------------------
