# %% [markdown]
# # Population and samples in statistics

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import numpy as np
import random
import statistics
import matplotlib.pyplot as plt
from IPython.display import Image

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# C:\Dev\Studium\Sem5\DA\data_analytics\Week_06

# %% [markdown]
# ## Car prices in Switzerland (simulated data)

# %%
Image("cars.jpg", width=800)

# %%
# Parameters of distribution
p_mean = 52000
p_std = 15000
p_n = 1000

# Setting a seed to restore the random numbers later
np.random.seed(42)

# Generate (normally distributed) data with mean = CHF 52000 and standard deviation = CHF 15000
pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)
print(f'{len(pop):.0f}')
print(f'{np.mean(pop):.4f}')
print(f'{np.std(pop):.4f}')

# Plot histogram based on the data
plt.hist(pop, bins = 50, color='gold')
plt.title('Car prices in Switzerland (simulated data)')
plt.xlabel('Price (CHF)')
plt.ylabel('Number of cars')

plt.show()
# Out:
# 1000
# 52289.9808
# 14680.8931

# %% [markdown]
# ## Single random sample from the population

# %%
# Sample size
sample_size = 200

# Set random seed for reproducibility
random.seed(42)

# Random sample from the population (without replacement)
random_sample = random.sample(list(pop), sample_size)

# Statistics of the sample
print(f'Mean: {statistics.mean(random_sample):.4f}')
print(f'Standard deviation: {statistics.stdev(random_sample):.4f}')

# Plot histogram based on the sample
plt.hist(random_sample, bins = 50, color='green')
plt.title(f'Car prices in Switzerland (sample with n={sample_size})', fontsize=10)
plt.xlabel('Price (CHF)')
plt.ylabel('Number of cars')

plt.show()
# Out:
# Mean: 53224.2676
# Standard deviation: 15301.0696

# %% [markdown]
# ### d) sample_size = 50

# %%
# Sample size
sample_size = 50

# Set random seed for reproducibility
random.seed(42)

# Random sample from the population (without replacement)
random_sample = random.sample(list(pop), sample_size)

# Statistics of the sample
print(f'Mean: {statistics.mean(random_sample):.4f}')
print(f'Standard deviation: {statistics.stdev(random_sample):.4f}')

# Plot histogram based on the sample
plt.hist(random_sample, bins = 50, color='green')
plt.title(f'Car prices in Switzerland (sample with n={sample_size})', fontsize=10)
plt.xlabel('Price (CHF)')
plt.ylabel('Number of cars')

plt.show()
# Out:
# Mean: 51741.6340
# Standard deviation: 16242.6233

# %% [markdown]
# ### d) sample_size = 500

# %%
# Sample size
sample_size = 500

# Set random seed for reproducibility
random.seed(42)

# Random sample from the population (without replacement)
random_sample = random.sample(list(pop), sample_size)

# Statistics of the sample
print(f'Mean: {statistics.mean(random_sample):.4f}')
print(f'Standard deviation: {statistics.stdev(random_sample):.4f}')

# Plot histogram based on the sample
plt.hist(random_sample, bins=50, color='green')
plt.title(f'Car prices in Switzerland (sample with n={sample_size})', fontsize=10)
plt.xlabel('Price (CHF)')
plt.ylabel('Number of cars')

plt.show()
# Out:
# Mean: 52791.9550
# Standard deviation: 15118.2981

# %% [markdown]
# ### d) sample_size = 1000

# %%
# Sample size
sample_size = 1000

# Set random seed for reproducibility
random.seed(42)

# Random sample from the population (without replacement)
random_sample = random.sample(list(pop), sample_size)

# Statistics of the sample
print(f'Mean: {statistics.mean(random_sample):.4f}')
print(f'Standard deviation: {statistics.stdev(random_sample):.4f}')

# Plot histogram based on the sample
plt.hist(random_sample, bins=50, color='green')
plt.title(f'Car prices in Switzerland (sample with n={sample_size})', fontsize=10)
plt.xlabel('Price (CHF)')
plt.ylabel('Number of cars')

plt.show()
# Out:
# Mean: 52289.9808
# Standard deviation: 14688.2391

# %% [markdown]
# ## Repeated random sampling 'with replacement' (bootstrapping)

# %%
def bootstrap(p_mean = 52000, p_std = 15000, p_n =1000, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std: Type = int, float
    :param p_n: Type = int, float
    :param num_iter: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    np.random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = np.random.choice(pop, size=sample_size, replace=True)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins = 50, color='mediumorchid')
    plt.title('Car prices in Switzerland (bootstrap sample)', fontsize=10)
    plt.xlabel('Price (CHF)')
    plt.ylabel('Number of cars')
    plt.show()

# Function call
bootstrap(p_mean=52000, p_std=15000, num_iter = 1000, sample_size = 200)
# Out:
# 52373.1510
# 14592.7569

# %% [markdown]
# ### d) sample_size = 500

# %%
def bootstrap(p_mean = 52000, p_std = 15000, p_n =1000, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std: Type = int, float
    :param p_n: Type = int, float
    :param num_iter: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    np.random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = np.random.choice(pop, size=sample_size, replace=True)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins = 50, color='mediumorchid')
    plt.title('Car prices in Switzerland (bootstrap sample)', fontsize=10)
    plt.xlabel('Price (CHF)')
    plt.ylabel('Number of cars')
    plt.show()

# Function call
bootstrap(p_mean=52000, p_std=15000, num_iter = 1000, sample_size = 500)
# Out:
# 52322.6687
# 14663.9894

# %% [markdown]
# ### d) sample_size = 100, num_iter = 7500

# %%
def bootstrap(p_mean = 52000, p_std = 15000, p_n =1000, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std: Type = int, float
    :param p_n: Type = int, float
    :param num_iter: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    np.random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = np.random.choice(pop, size=sample_size, replace=True)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins = 50, color='mediumorchid')
    plt.title('Car prices in Switzerland (bootstrap sample)', fontsize=10)
    plt.xlabel('Price (CHF)')
    plt.ylabel('Number of cars')
    plt.show()

# Function call
bootstrap(p_mean=52000, p_std=15000, num_iter = 7500, sample_size = 100)
# Out:
# 52306.7218
# 14570.1496

# %% [markdown]
# ### d) sample_size = 50, num_iter = 2500

# %%
def bootstrap(p_mean = 52000, p_std = 15000, p_n =1000, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std: Type = int, float
    :param p_n: Type = int, float
    :param num_iter: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    np.random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = np.random.choice(pop, size=sample_size, replace=True)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins = 50, color='mediumorchid')
    plt.title('Car prices in Switzerland (bootstrap sample)', fontsize=10)
    plt.xlabel('Price (CHF)')
    plt.ylabel('Number of cars')
    plt.show()

# Function call
bootstrap(p_mean=52000, p_std=15000, num_iter = 2500, sample_size = 50)
# Out:
# 52392.0609
# 14401.4710

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 11
# Datetime: 2025-10-28 17:20:07
# Python Version: 3.13.7
# -----------------------------------
